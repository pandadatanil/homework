# %%
import pandas as pd

# %%
url = 'https://data.cityofnewyork.us/resource/2j8u-wtju.csv'

# %%
limit = 12000

# %%
url2 = f'{url}?$limit={limit}'

# %%
df = pd.read_csv(url2)

# %%
df
# Out:
#       unique_id_number program_code language  \
# 0               P085en          NaN  English
# 1               P099en          NaN  English
# 2               P095en          NaN  English
# 3               P102en          NaN  English
# 4               P103en          NaN  English
# ...                ...          ...      ...
# 10748           P029en       S2R029  English
# 10749           P047en          NaN  English
# 10750           P024en       S2R024  English
# 10751           P021en       S2R021  English
# 10752           P032en       S2R032  English
#
#                                             program_name program_acronym  \
# 0                                            3-K for All             3-K
# 1                                              Jobs Plus             NaN
# 2                                     Train & Earn\u200b             NaN
# 3                                          NYCitizenship             NaN
# ...
